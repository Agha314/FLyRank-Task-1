# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Agha314/FLyRank-Task-1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### Lane 2 - Refresh / Content Opportunity Scoring
# Content naturally decays over time. The starter pipeline proves that a learned ranking model (like a random forest) can identify at-risk pages much more accurately than static rules. This lane is worth the next 7 weeks because it allows me to build a practical decision-support tool that will save editorial time and capture lost traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **The Question:** Which specific web pages show the highest risk of decline or the best opportunity for recovery, and should therefore be reviewed first?
#
# **Unit of Analysis:** A single pseudonymized content item.
#
# **The Decision:** Choosing which pages the editorial team should prioritize for review with their limited capacity.
#
# **The Action:** A reviewer updates the content, fixes the metadata, or prunes the page.
#
# **Cost of a Wrong Call:** If the recommendation is wrong, the team wastes valuable editorial time on a healthy page while truly declining pages continue to lose traffic.
#
# **Why ML helps:** The content inventory is too large for manual review. A model can weigh multiple signals simultaneously to rank opportunities better than rigid rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content/content_refresh_anonymized.csv")

eligible_pages = df[(df['content_age_days'] >= 90) & (df['impressions_90d'] > 0)]

# Percentage of eligible pages that are currently trending downward
downward_trend_pct = (eligible_pages['trend_direction'] == 'down').mean() * 100

print(f"Number 1: The starter dataset contains {len(df):,} total content rows.")
print(f"Number 2: There are {len(eligible_pages):,} eligible pages with established history to analyze.")
print(f"Number 3: {downward_trend_pct:.1f}% of these eligible pages are experiencing a downward trend.")
# Out:
# Number 1: The starter dataset contains 30,000 total content rows.
# Number 2: There are 30,000 eligible pages with established history to analyze.
# Number 3: 54.2% of these eligible pages are experiencing a downward trend.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What I can claim:** I can show observational evidence linking content signals to traffic movement. I can provide a ranked list to make the review process more efficient.
#
# **What I cannot claim:** I cannot claim that updating a page will guarantee traffic recovery, as this data is observational and not a causal experiment. I cannot identify real URLs or client names because the data is pseudonymized.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
